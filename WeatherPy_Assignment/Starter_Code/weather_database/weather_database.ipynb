# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random as rd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})
     
            
       
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yining
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | tigil
# Processing Record 4 of Set 1 | the valley
# Processing Record 5 of Set 1 | boende
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | tchaourou
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | ewa beach
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | santa maria del oro
# Processing Record 13 of Set 1 | srednekolymsk
# Processing Record 14 of Set 1 | tommot
# Processing Record 15 of Set 1 | adrar
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | san cristobal
# Processing Record 19 of Set 1 | letlhakeng
# Processing Record 20 of Set 1 | buala
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | athol
# Processing Record 23 of Set 1 | broome
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | muisne
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | faya
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | general roca
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | paamiut
# Processing Record 40 of Set 1 | nuuk
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | lipari
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | vostok
# Processing Record 49 of Set 1 | worthington
# Processing Record 50 of Set 1 | rio grande
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | sindand
# City not found. Skipping...
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | kloulklubed
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | kemijarvi
# Processing Record 11 of Set 2 | bilma
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | awjilah
# Processing Record 14 of Set 2 | lima
# Processing Record 15 of Set 2 | gigmoto
# Processing Record 16 of Set 2 | taian
# Processing Record 17 of Set 2 | luganville
# Processing Record 18 of Set 2 | ayagoz
# Processing Record 19 of Set 2 | northam
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | margate
# Processing Record 26 of Set 2 | progreso
# Processing Record 27 of Set 2 | saint-joseph
# Processing Record 28 of Set 2 | hammerfest
# Processing Record 29 of Set 2 | umarkot
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | floro
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | sorland
# Processing Record 35 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 2 | south lake tahoe
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | tromso
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 2 | natal
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | lerwick
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | shimanovsk
# Processing Record 50 of Set 2 | qaqortoq
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | hami
# Processing Record 3 of Set 3 | chipinge
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | itarema
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | nongstoin
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | sterling
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | nemuro
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | kihei
# Processing Record 20 of Set 3 | turayf
# Processing Record 21 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | fukue
# Processing Record 24 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 3 | atambua
# Processing Record 26 of Set 3 | velizh
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | port keats
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | batemans bay
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | batagay-alyta
# Processing Record 34 of Set 3 | chifeng
# Processing Record 35 of Set 3 | khani
# Processing Record 36 of Set 3 | amuntai
# Processing Record 37 of Set 3 | abha
# Processing Record 38 of Set 3 | bell ville
# Processing Record 39 of Set 3 | coihaique
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | provost
# Processing Record 42 of Set 3 | valleyview
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 3 | deputatskiy
# Processing Record 46 of Set 3 | sinnamary
# Processing Record 47 of Set 3 | wahpeton
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | neuquen
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | vestmanna
# Processing Record 2 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 4 | roald
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | aspindza
# Processing Record 6 of Set 4 | fuyu
# Processing Record 7 of Set 4 | duayaw nkwanta
# Processing Record 8 of Set 4 | lompoc
# Processing Record 9 of Set 4 | bonfim
# Processing Record 10 of Set 4 | changping
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | henties bay
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | bathsheba
# Processing Record 16 of Set 4 | chingirlau
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | boa vista
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 4 | hualmay
# Processing Record 23 of Set 4 | mandalgovi
# Processing Record 24 of Set 4 | solvychegodsk
# Processing Record 25 of Set 4 | sur
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | odweyne
# Processing Record 28 of Set 4 | virden
# Processing Record 29 of Set 4 | babu
# Processing Record 30 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 4 | prince rupert
# Processing Record 32 of Set 4 | bairiki
# Processing Record 33 of Set 4 | jamestown
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | grindavik
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | dumas
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | mayo
# Processing Record 41 of Set 4 | moron
# Processing Record 42 of Set 4 | esso
# Processing Record 43 of Set 4 | phayao
# Processing Record 44 of Set 4 | oranjestad
# Processing Record 45 of Set 4 | dalbandin
# Processing Record 46 of Set 4 | yakeshi
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | erzin
# Processing Record 49 of Set 4 | san andres
# Processing Record 50 of Set 4 | weston
# Processing Record 1 of Set 5 | samana
# Processing Record 2 of Set 5 | kisangani
# Processing Record 3 of Set 5 | fairbanks
# Processing Record 4 of Set 5 | yinchuan
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | krasnoselkup
# Processing Record 7 of Set 5 | pacific grove
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | qaanaaq
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | luanda
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | fayaoue
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | biak
# Processing Record 18 of Set 5 | maykor
# Processing Record 19 of Set 5 | bambous virieux
# Processing Record 20 of Set 5 | ponta delgada
# Processing Record 21 of Set 5 | maceio
# Processing Record 22 of Set 5 | emerald
# Processing Record 23 of Set 5 | roma
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | bataipora
# Processing Record 26 of Set 5 | mankono
# Processing Record 27 of Set 5 | oxford
# Processing Record 28 of Set 5 | jinchang
# Processing Record 29 of Set 5 | qujing
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | bengkulu
# Processing Record 32 of Set 5 | hurricane
# Processing Record 33 of Set 5 | ancud
# Processing Record 34 of Set 5 | rodrigues alves
# Processing Record 35 of Set 5 | trhove sviny
# Processing Record 36 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 5 | madimba
# Processing Record 38 of Set 5 | moratuwa
# Processing Record 39 of Set 5 | crangeni
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | sovetskiy
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | renfrew
# Processing Record 44 of Set 5 | caravelas
# Processing Record 45 of Set 5 | paignton
# Processing Record 46 of Set 5 | taksimo
# Processing Record 47 of Set 5 | bijar
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | berlevag
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | belmonte
# Processing Record 2 of Set 6 | hamilton
# Processing Record 3 of Set 6 | mansehra
# Processing Record 4 of Set 6 | gat
# Processing Record 5 of Set 6 | limon
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | hay river
# Processing Record 8 of Set 6 | ingham
# Processing Record 9 of Set 6 | sambava
# Processing Record 10 of Set 6 | coruripe
# Processing Record 11 of Set 6 | lososina
# Processing Record 12 of Set 6 | karpathos
# Processing Record 13 of Set 6 | bella union
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | bluefield
# Processing Record 16 of Set 6 | channel-port aux basques
# Processing Record 17 of Set 6 | mar del plata
# Processing Record 18 of Set 6 | barrow
# Processing Record 19 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 6 | lucapa
# Processing Record 21 of Set 6 | sahbuz
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | camalu
# Processing Record 24 of Set 6 | kaduqli
# Processing Record 25 of Set 6 | muros
# Processing Record 26 of Set 6 | pemba
# Processing Record 27 of Set 6 | shahr-e kord
# Processing Record 28 of Set 6 | puerto madero
# Processing Record 29 of Set 6 | hasaki
# Processing Record 30 of Set 6 | olafsvik
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | truro
# Processing Record 33 of Set 6 | san ramon
# Processing Record 34 of Set 6 | lufilufi
# Processing Record 35 of Set 6 | huilong
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | egvekinot
# Processing Record 38 of Set 6 | matay
# Processing Record 39 of Set 6 | bom conselho
# Processing Record 40 of Set 6 | sandwick
# Processing Record 41 of Set 6 | banda aceh
# Processing Record 42 of Set 6 | doctor arroyo
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | pochutla
# Processing Record 45 of Set 6 | asyut
# Processing Record 46 of Set 6 | angoche
# Processing Record 47 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 6 | dahuk
# Processing Record 49 of Set 6 | viedma
# Processing Record 50 of Set 6 | ilhabela
# Processing Record 1 of Set 7 | ordubad
# Processing Record 2 of Set 7 | gilbues
# Processing Record 3 of Set 7 | vardo
# Processing Record 4 of Set 7 | enshi
# Processing Record 5 of Set 7 | aranos
# Processing Record 6 of Set 7 | goderich
# Processing Record 7 of Set 7 | katsuura
# Processing Record 8 of Set 7 | tshela
# Processing Record 9 of Set 7 | chongoyape
# Processing Record 10 of Set 7 | aykhal
# Processing Record 11 of Set 7 | noshiro
# Processing Record 12 of Set 7 | jiexiu
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | chapleau
# Processing Record 15 of Set 7 | yambio
# Processing Record 16 of Set 7 | alihe
# Processing Record 17 of Set 7 | walvis bay
# Processing Record 18 of Set 7 | buin
# Processing Record 19 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 7 | coahuayana
# Processing Record 21 of Set 7 | rock springs
# Processing Record 22 of Set 7 | kasongo-lunda
# Processing Record 23 of Set 7 | bulawayo
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | ambilobe
# Processing Record 27 of Set 7 | opuwo
# Processing Record 28 of Set 7 | fortuna
# Processing Record 29 of Set 7 | ulladulla
# Processing Record 30 of Set 7 | ust-kuyga
# Processing Record 31 of Set 7 | nabire
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | hovd
# Processing Record 34 of Set 7 | smiltene
# Processing Record 35 of Set 7 | nador
# Processing Record 36 of Set 7 | khash
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | ciudad bolivar
# Processing Record 40 of Set 7 | kiruna
# Processing Record 41 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 7 | vila velha
# Processing Record 43 of Set 7 | jian
# Processing Record 44 of Set 7 | derzhavinsk
# Processing Record 45 of Set 7 | hays
# Processing Record 46 of Set 7 | la asuncion
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | saint george
# Processing Record 49 of Set 7 | pisco
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | princeton
# Processing Record 2 of Set 8 | rawson
# Processing Record 3 of Set 8 | brits
# Processing Record 4 of Set 8 | bobcaygeon
# Processing Record 5 of Set 8 | san joaquin
# Processing Record 6 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 8 | kirakira
# Processing Record 8 of Set 8 | chimbote
# Processing Record 9 of Set 8 | sidi qasim
# City not found. Skipping...
# Processing Record 10 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 8 | salmo
# Processing Record 12 of Set 8 | yerbogachen
# Processing Record 13 of Set 8 | siderno
# Processing Record 14 of Set 8 | jaisalmer
# Processing Record 15 of Set 8 | virginia beach
# Processing Record 16 of Set 8 | serpa
# Processing Record 17 of Set 8 | uarini
# Processing Record 18 of Set 8 | hurghada
# Processing Record 19 of Set 8 | kozloduj
# City not found. Skipping...
# Processing Record 20 of Set 8 | atar
# Processing Record 21 of Set 8 | san-pedro
# Processing Record 22 of Set 8 | evensk
# Processing Record 23 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | peterhead
# Processing Record 27 of Set 8 | gambela
# Processing Record 28 of Set 8 | thongwa
# Processing Record 29 of Set 8 | termoli
# Processing Record 30 of Set 8 | shaoyang
# Processing Record 31 of Set 8 | huntsville
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | tiksi
# Processing Record 34 of Set 8 | am timan
# Processing Record 35 of Set 8 | chancay
# Processing Record 36 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 8 | bariri
# Processing Record 38 of Set 8 | bandarbeyla
# Processing Record 39 of Set 8 | upernavik
# Processing Record 40 of Set 8 | brownwood
# Processing Record 41 of Set 8 | ust-koksa
# Processing Record 42 of Set 8 | svarstad
# Processing Record 43 of Set 8 | cascais
# Processing Record 44 of Set 8 | mehamn
# Processing Record 45 of Set 8 | katangli
# Processing Record 46 of Set 8 | yar-sale
# Processing Record 47 of Set 8 | lewistown
# Processing Record 48 of Set 8 | banamba
# Processing Record 49 of Set 8 | nesbyen
# Processing Record 50 of Set 8 | manggar
# Processing Record 1 of Set 9 | akyab
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | myitkyina
# Processing Record 5 of Set 9 | belvedere marittimo
# Processing Record 6 of Set 9 | brora
# Processing Record 7 of Set 9 | prado
# Processing Record 8 of Set 9 | winnemucca
# Processing Record 9 of Set 9 | bud
# Processing Record 10 of Set 9 | kushmurun
# Processing Record 11 of Set 9 | piura
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | toowoomba
# Processing Record 14 of Set 9 | grand gaube
# Processing Record 15 of Set 9 | alta floresta
# Processing Record 16 of Set 9 | russell
# Processing Record 17 of Set 9 | menongue
# Processing Record 18 of Set 9 | yazoo city
# Processing Record 19 of Set 9 | dhidhdhoo
# Processing Record 20 of Set 9 | moree
# Processing Record 21 of Set 9 | pandan
# Processing Record 22 of Set 9 | kreuzlingen
# Processing Record 23 of Set 9 | half moon bay
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | araouane
# Processing Record 26 of Set 9 | springbok
# Processing Record 27 of Set 9 | rocha
# Processing Record 28 of Set 9 | wana
# Processing Record 29 of Set 9 | sivas
# Processing Record 30 of Set 9 | santa maria
# Processing Record 31 of Set 9 | orlik
# Processing Record 32 of Set 9 | lovozero
# Processing Record 33 of Set 9 | mbandaka
# Processing Record 34 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 35 of Set 9 | guanhaes
# Processing Record 36 of Set 9 | irituia
# Processing Record 37 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 9 | codrington
# Processing Record 40 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 9 | tynda
# Processing Record 42 of Set 9 | tchamba
# Processing Record 43 of Set 9 | chandpur
# Processing Record 44 of Set 9 | shizuishan
# Processing Record 45 of Set 9 | lindon
# Processing Record 46 of Set 9 | sayyan
# Processing Record 47 of Set 9 | daru
# Processing Record 48 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 9 | shitanjing
# Processing Record 50 of Set 9 | southampton
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | iqaluit
# Processing Record 3 of Set 10 | seoul
# Processing Record 4 of Set 10 | port-gentil
# Processing Record 5 of Set 10 | kimbe
# Processing Record 6 of Set 10 | tilichiki
# Processing Record 7 of Set 10 | saurimo
# Processing Record 8 of Set 10 | svetlogorsk
# Processing Record 9 of Set 10 | chkalovsk
# Processing Record 10 of Set 10 | cedar city
# Processing Record 11 of Set 10 | rabak
# Processing Record 12 of Set 10 | karasjok
# Processing Record 13 of Set 10 | nome
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | tabuk
# Processing Record 17 of Set 10 | bantou
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | balashov
# Processing Record 20 of Set 10 | cadiz
# Processing Record 21 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 10 | mae hong son
# Processing Record 23 of Set 10 | santa rosa
# Processing Record 24 of Set 10 | cordoba
# Processing Record 25 of Set 10 | kupang
# Processing Record 26 of Set 10 | san juan tecuaco
# Processing Record 27 of Set 10 | khuzhir
# Processing Record 28 of Set 10 | kiama
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | umm lajj
# Processing Record 31 of Set 10 | nelson bay
# Processing Record 32 of Set 10 | ixtapa
# Processing Record 33 of Set 10 | karla
# Processing Record 34 of Set 10 | gannan
# Processing Record 35 of Set 10 | glogow
# Processing Record 36 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 10 | razole
# Processing Record 38 of Set 10 | aramaywan
# City not found. Skipping...
# Processing Record 39 of Set 10 | chipoka
# Processing Record 40 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 41 of Set 10 | kruisfontein
# Processing Record 42 of Set 10 | dandong
# Processing Record 43 of Set 10 | bara
# Processing Record 44 of Set 10 | horana
# Processing Record 45 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 10 | peseux
# Processing Record 47 of Set 10 | wageningen
# Processing Record 48 of Set 10 | shwebo
# Processing Record 49 of Set 10 | pierre
# Processing Record 50 of Set 10 | okhotsk
# Processing Record 1 of Set 11 | malanje
# Processing Record 2 of Set 11 | camacha
# Processing Record 3 of Set 11 | makakilo city
# Processing Record 4 of Set 11 | elko
# Processing Record 5 of Set 11 | sibu
# Processing Record 6 of Set 11 | lasa
# Processing Record 7 of Set 11 | shenjiamen
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | gizo
# Processing Record 10 of Set 11 | santa cruz cabralia
# Processing Record 11 of Set 11 | santa margherita ligure
# Processing Record 12 of Set 11 | isangel
# Processing Record 13 of Set 11 | anzio
# Processing Record 14 of Set 11 | hecun
# Processing Record 15 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 11 | mao
# Processing Record 17 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 11 | ormara
# Processing Record 19 of Set 11 | turangi
# Processing Record 20 of Set 11 | baykit
# Processing Record 21 of Set 11 | leeton
# Processing Record 22 of Set 11 | san bartolome de tirajana
# Processing Record 23 of Set 11 | lander
# Processing Record 24 of Set 11 | muli
# Processing Record 25 of Set 11 | tyulgan
# Processing Record 26 of Set 11 | megion
# Processing Record 27 of Set 11 | galesong
# Processing Record 28 of Set 11 | los llanos de aridane
# Processing Record 29 of Set 11 | toamasina
# Processing Record 30 of Set 11 | umm kaddadah
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 11 | pervoye maya
# Processing Record 34 of Set 11 | sawtell
# Processing Record 35 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 36 of Set 11 | seminole
# Processing Record 37 of Set 11 | ola
# Processing Record 38 of Set 11 | namwala
# Processing Record 39 of Set 11 | foam lake
# Processing Record 40 of Set 11 | rawlins
# Processing Record 41 of Set 11 | chara
# Processing Record 42 of Set 11 | murdochville
# Processing Record 43 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 11 | ferrol
# Processing Record 45 of Set 11 | mombaca
# Processing Record 46 of Set 11 | vilhena
# Processing Record 47 of Set 11 | morehead
# Processing Record 48 of Set 11 | sao gabriel da cachoeira
# Processing Record 49 of Set 11 | buchanan
# Processing Record 50 of Set 11 | voznesenskoye
# Processing Record 1 of Set 12 | tura
# Processing Record 2 of Set 12 | shushtar
# Processing Record 3 of Set 12 | yulara
# Processing Record 4 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 12 | sobolevo
# Processing Record 6 of Set 12 | arman
# Processing Record 7 of Set 12 | sao jose da coroa grande
# Processing Record 8 of Set 12 | giresun
# Processing Record 9 of Set 12 | jimo
# Processing Record 10 of Set 12 | honggang
# Processing Record 11 of Set 12 | ilulissat
# Processing Record 12 of Set 12 | vieques
# Processing Record 13 of Set 12 | muscle shoals
# Processing Record 14 of Set 12 | santa cruz de la palma
# Processing Record 15 of Set 12 | jinji
# Processing Record 16 of Set 12 | flinders
# Processing Record 17 of Set 12 | amahai
# Processing Record 18 of Set 12 | ninghai
# Processing Record 19 of Set 12 | port hawkesbury
# Processing Record 20 of Set 12 | muana
# Processing Record 21 of Set 12 | uvinza
# Processing Record 22 of Set 12 | niquelandia
# Processing Record 23 of Set 12 | hobyo
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | cairns
# Processing Record 26 of Set 12 | churapcha
# Processing Record 27 of Set 12 | dzaoudzi
# Processing Record 28 of Set 12 | cidreira
# Processing Record 29 of Set 12 | waipawa
# Processing Record 30 of Set 12 | amurzet
# Processing Record 31 of Set 12 | laguna
# Processing Record 32 of Set 12 | sungairaya
# Processing Record 33 of Set 12 | yelets
# Processing Record 34 of Set 12 | rosarito
# Processing Record 35 of Set 12 | agadir
# Processing Record 36 of Set 12 | sakakah
# Processing Record 37 of Set 12 | benguela
# Processing Record 38 of Set 12 | tallahassee
# Processing Record 39 of Set 12 | ayan
# Processing Record 40 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 12 | vice
# Processing Record 42 of Set 12 | the pas
# Processing Record 43 of Set 12 | kabanjahe
# Processing Record 44 of Set 12 | sompeta
# Processing Record 45 of Set 12 | sunamganj
# City not found. Skipping...
# Processing Record 46 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 47 of Set 12 | nioro
# Processing Record 48 of Set 12 | el sauz
# Processing Record 49 of Set 12 | mackenzie
# Processing Record 50 of Set 12 | marawi
# Processing Record 1 of Set 13 | mizdah
# Processing Record 2 of Set 13 | balikpapan
# Processing Record 3 of Set 13 | agirish
# Processing Record 4 of Set 13 | aklavik
# Processing Record 5 of Set 13 | mamallapuram
# Processing Record 6 of Set 13 | yumen
# Processing Record 7 of Set 13 | valparaiso
# Processing Record 8 of Set 13 | horsham
# Processing Record 9 of Set 13 | shimoda
# Processing Record 10 of Set 13 | poddorye
# Processing Record 11 of Set 13 | anchorage
# Processing Record 12 of Set 13 | nova olimpia
# Processing Record 13 of Set 13 | shieli
# Processing Record 14 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 15 of Set 13 | dunedin
# Processing Record 16 of Set 13 | nyurba
# Processing Record 17 of Set 13 | tazovskiy
# Processing Record 18 of Set 13 | kuryk
# Processing Record 19 of Set 13 | linhares
# Processing Record 20 of Set 13 | udachnyy
# Processing Record 21 of Set 13 | necochea
# Processing Record 22 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 13 | sept-iles
# Processing Record 24 of Set 13 | skjervoy
# Processing Record 25 of Set 13 | vysokogornyy
# Processing Record 26 of Set 13 | najran
# Processing Record 27 of Set 13 | komsomolskiy
# Processing Record 28 of Set 13 | anadyr
# Processing Record 29 of Set 13 | broken hill
# Processing Record 30 of Set 13 | berbera
# Processing Record 31 of Set 13 | wewak
# Processing Record 32 of Set 13 | mount gambier
# Processing Record 33 of Set 13 | zhigansk
# Processing Record 34 of Set 13 | yaan
# Processing Record 35 of Set 13 | havelock
# Processing Record 36 of Set 13 | sokna
# Processing Record 37 of Set 13 | vangaindrano
# Processing Record 38 of Set 13 | butembo
# Processing Record 39 of Set 13 | rioja
# Processing Record 40 of Set 13 | beyneu
# Processing Record 41 of Set 13 | diamantino
# Processing Record 42 of Set 13 | nahan
# Processing Record 43 of Set 13 | mayya
# Processing Record 44 of Set 13 | morondava
# Processing Record 45 of Set 13 | belaya gora
# Processing Record 46 of Set 13 | onega
# Processing Record 47 of Set 13 | shetpe
# Processing Record 48 of Set 13 | sangar
# Processing Record 49 of Set 13 | el sauzal
# Processing Record 50 of Set 13 | pacifica
# Processing Record 1 of Set 14 | suclayin
# Processing Record 2 of Set 14 | merauke
# Processing Record 3 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 4 of Set 14 | erenhot
# Processing Record 5 of Set 14 | samarai
# Processing Record 6 of Set 14 | porto empedocle
# Processing Record 7 of Set 14 | kassala
# Processing Record 8 of Set 14 | chunan
# Processing Record 9 of Set 14 | ugoofaaru
# Processing Record 10 of Set 14 | yoichi
# Processing Record 11 of Set 14 | nouadhibou
# Processing Record 12 of Set 14 | talaya
# Processing Record 13 of Set 14 | khromtau
# Processing Record 14 of Set 14 | leshukonskoye
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | sabang
# Processing Record 17 of Set 14 | severo-kurilsk
# Processing Record 18 of Set 14 | martapura
# Processing Record 19 of Set 14 | san policarpo
# Processing Record 20 of Set 14 | formosa
# Processing Record 21 of Set 14 | vallenar
# Processing Record 22 of Set 14 | youkounkoun
# Processing Record 23 of Set 14 | pangkalanbuun
# Processing Record 24 of Set 14 | parrita
# Processing Record 25 of Set 14 | zhangye
# Processing Record 26 of Set 14 | forestville
# Processing Record 27 of Set 14 | dese
# Processing Record 28 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 14 | hofn
# Processing Record 30 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 31 of Set 14 | xiuyan
# Processing Record 32 of Set 14 | zaysan
# Processing Record 33 of Set 14 | alto araguaia
# Processing Record 34 of Set 14 | juneau
# Processing Record 35 of Set 14 | tual
# Processing Record 36 of Set 14 | matagami
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | bayan
# Processing Record 39 of Set 14 | guarda
# Processing Record 40 of Set 14 | veshkayma
# Processing Record 41 of Set 14 | kwinana
# Processing Record 42 of Set 14 | chimoio
# Processing Record 43 of Set 14 | noyabrsk
# Processing Record 44 of Set 14 | leh
# Processing Record 45 of Set 14 | fuxin
# Processing Record 46 of Set 14 | soe
# Processing Record 47 of Set 14 | kapuskasing
# Processing Record 48 of Set 14 | friesoythe
# Processing Record 49 of Set 14 | lebedyn
# Processing Record 50 of Set 14 | finschhafen
# Processing Record 1 of Set 15 | xining
# Processing Record 2 of Set 15 | ossora
# Processing Record 3 of Set 15 | malibu
# Processing Record 4 of Set 15 | thunder bay
# Processing Record 5 of Set 15 | bereda
# Processing Record 6 of Set 15 | grand-santi
# Processing Record 7 of Set 15 | antofagasta
# Processing Record 8 of Set 15 | big spring
# Processing Record 9 of Set 15 | tezu
# Processing Record 10 of Set 15 | hoquiam
# Processing Record 11 of Set 15 | mersing
# Processing Record 12 of Set 15 | gedo
# Processing Record 13 of Set 15 | ravar
# Processing Record 14 of Set 15 | saint-augustin
# Processing Record 15 of Set 15 | bubaque
# Processing Record 16 of Set 15 | gerash
# Processing Record 17 of Set 15 | ketchikan
# Processing Record 18 of Set 15 | trinidad
# Processing Record 19 of Set 15 | grand-bourg
# Processing Record 20 of Set 15 | khandyga
# Processing Record 21 of Set 15 | noumea
# Processing Record 22 of Set 15 | athabasca
# Processing Record 23 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | carutapera
# Processing Record 25 of Set 15 | ginir
# Processing Record 26 of Set 15 | atbasar
# Processing Record 27 of Set 15 | aquin
# Processing Record 28 of Set 15 | palauig
# Processing Record 29 of Set 15 | carazinho
# Processing Record 30 of Set 15 | klyuchi
# Processing Record 31 of Set 15 | gulbarga
# Processing Record 32 of Set 15 | mweka
# Processing Record 33 of Set 15 | poltavka
# Processing Record 34 of Set 15 | taoudenni
# Processing Record 35 of Set 15 | wabana
# Processing Record 36 of Set 15 | mangrol
# Processing Record 37 of Set 15 | beruni
# City not found. Skipping...
# Processing Record 38 of Set 15 | luena
# Processing Record 39 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 15 | vasilkovo
# City not found. Skipping...
# Processing Record 41 of Set 15 | inuvik
# Processing Record 42 of Set 15 | nsoko
# Processing Record 43 of Set 15 | vale
# Processing Record 44 of Set 15 | dodola
# Processing Record 45 of Set 15 | ulaanbaatar
# Processing Record 46 of Set 15 | acapulco
# Processing Record 47 of Set 15 | puerto madryn
# Processing Record 48 of Set 15 | karimpur
# Processing Record 49 of Set 15 | kieta
# Processing Record 50 of Set 15 | kumbo
# Processing Record 1 of Set 16 | burica
# City not found. Skipping...
# Processing Record 2 of Set 16 | taltal
# Processing Record 3 of Set 16 | zabol
# Processing Record 4 of Set 16 | iwanai
# Processing Record 5 of Set 16 | puerto baquerizo moreno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Yining  29.0361  114.5636     36.07        48           6
# 1       Rikitea -23.1203 -134.9692     77.76        71          15
# 2         Tigil  57.8000  158.6667     14.52        85          97
# 3    The Valley  18.2170  -63.0578     82.54        65          20
# 4        Boende  -0.2167   20.8667     70.43        97          93
# 5         Bluff -46.6000  168.3333     59.05        83          60
# 6     Tchaourou   8.8865    2.5975     78.01        21          81
# 7       Ushuaia -54.8000  -68.3000     64.06        55           0
# 8     Ewa Beach  21.3156 -158.0072     80.10        73          75
# 9  Puerto Ayora  -0.7393  -90.3518     80.56        92          62
#
#    Wind Speed Country                 Date Current Description
# 0        2.17      CN  2022-12-22 20:55:48           clear sky
# 1        5.77      PF  2022-12-22 20:55:49          few clouds
# 2        6.22      RU  2022-12-22 20:55:50     overcast clouds
# 3       13.80      AI  2022-12-22 20:55:51          few clouds
# 4        2.01      CD  2022-12-22 20:55:52          light rain
# 5        7.45      NZ  2022-12-22 20:52:14       broken clouds
# 6        6.82      BJ  2022-12-22 20:55:53       broken clouds
# 7        5.75      AR  2022-12-22 20:55:53           clear sky
# 8        4.00      US  2022-12-22 20:55:54       broken clouds
# 9        4.00      EC  2022-12-22 20:55:55       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_df = city_data_df[['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']]
city_d
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     Yining      CN  29.0361  114.5636     36.07        48
# 1                    Rikitea      PF -23.1203 -134.9692     77.76        71
# 2                      Tigil      RU  57.8000  158.6667     14.52        85
# 3                 The Valley      AI  18.2170  -63.0578     82.54        65
# 4                     Boende      CD  -0.2167   20.8667     70.43        97
# ..                       ...     ...      ...       ...       ...       ...
# 687                    Kumbo      CM   6.2000   10.6667     59.41        44
# 688                   Taltal      CL -25.4000  -70.4833     72.23        62
# 689                    Zabol      AF  32.2500   67.2500     31.91        58
# 690                   Iwanai      JP  42.9744  140.5089     35.55        98
# 691  Puerto Baquerizo Moreno      EC  -0.9000  -89.6000     76.19        83
#
#      Cloudiness  Wind Speed Current Description
# 0             6        2.17           clear sky
# 1            15        5.77          few clouds
# 2            97        6.22     overcast clouds
# 3            20       13.80          few clouds
# 4            93        2.01          light rain
# ..          ...         ...                 ...
# 687          52        5.84       broken clouds
# 688          21        5.41          few clouds
# 689           0        6.44           clear sky
# 690         100        4.81          light rain
# 691          75        6.91       broken clouds
#
# [692 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../weather_database/cities.csv"

# Export the city_data DataFrame into a CSV file
city_df.to_csv(output_data_file, index_label="City_ID")
